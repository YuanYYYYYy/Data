# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
interest_rate=pd.read_csv('/content/gdrive/MyDrive/JPM/Interest Rate/Interest_30_UK.csv',index_col=[0])

# %%
import os
path = "/content/gdrive/MyDrive/JPM/UK_data/UK_Speech/"
os.chdir(path)
os.listdir(path)
file_list=[i for i in os.listdir(path) if 'txt' in i]

# %%
speech_text=dict()
for i in range(len(file_list)):
  f=open(path+file_list[i],'r',encoding='latin1')
  f1=f.readlines()
  contents=[]
  for line in f1:
    if ('[SECTION]' not in line):
      if len(line.strip().split(' '))>=5:
        if ('Voting for the FOMC monetary policy action were' in line):
          break
        contents.append(line.strip())
  text = ' '.join(contents)
  text=text.replace('â','')
  text=text.replace('ï','')
  text=text.replace('All speeches are available online at www.bankofengland.co.uk/publications/Pages/speeches/default.aspx','')
  text=text.replace('All speeches are available online at www.bankofengland.co.uk/publications/speeches','')
  if len(text.split(' '))>100:
    speech_text[file_list[i][:8]]='speech '+text
  else:
    print(i,len(text.split(' ')),text)
# Out:
# 36 84 Page 1 Inclusive Capitalism Conference: In Conversation with Governor Mark Carney Given at Mansion House, LondonPage 2 Published on 26 June 2015 Governor Mark Carney participates in an on-stage conversation with The Economists Editor-in- Chief Zanny Minton-Beddoes at the Conference on Inclusive Capitalism: The Pathway to Action. The Governor discusses how we can create core financial markets that work fairly and effectively to deliver strong, sustainable and balanced growth. Mark Carney Former Governor, Bank of England from 2013 to 2020 Â©2022 Bank of England
# 308 32 Page 1 Consumption and Interest Rates - speech by Tim Besley Given at Centre for Economic Policy ResearchPage 2 Published on 19 July 2007 Consumption and Interest Rates Â©2022 Bank of England
# 455 29 Page 1 Interpreting Monetary Policy - speech by David Miles Speech given at Imperial College, LondonPage 2 Published on 25 February 2010 Interpreting Monetary Policy Â©2022 Bank of England
# 633 53 Page 1 Momentum in the housing market: affordability, indebtedness and risks - speech by Sir Jon Cunliffe Given at the Worshipful Company of International Bankers dinner, LondonPage 2 Published on 01 May 2014 Momentum in the housing market: affordability, indebtedness and risks - speech by Sir Jon Cunliffe  Â©2022 Bank of England
# 848 43 Page 1 A Perspective on Recent Monetary and Financial System Developments - speech by Paul Tucker Speech given at the Merrill Lynch Conference, LondonPage 2 Published on 26 April 2007 A Perspective on Recent Monetary and Financial System Developments Â©2022 Bank of England
# 931 35 Annex 1    Focus Areas from CPMI Stage 2 report to the G20, July 2020    Enhancing cross-border payments: building blocks of a global roadmap - Technical background note  (bis.org)

# %%
import os
path = "/content/gdrive/MyDrive/JPM/UK_data/UK_minutes/"
os.chdir(path)
os.listdir(path)
file_list=[i for i in os.listdir(path) if 'txt' in i]

# %%
minutes_text=dict()
for i in range(len(file_list)):
  f=open(path+file_list[i],'r',encoding='latin1')
  f1=f.readlines()
  contents=[]
  for line in f1:
    if ('[SECTION]' not in line):
      if len(line.strip().split(' '))>=5:
        if ('Voting for the FOMC monetary policy action were' in line):
          break
        contents.append(line.strip())
  text = ' '.join(contents)
  text=text.replace('â','')
  text=text.replace('ï','')
  text=text.replace('All speeches are available online at www.bankofengland.co.uk/publications/Pages/speeches/default.aspx','')
  text=text.replace('All speeches are available online at www.bankofengland.co.uk/publications/speeches','')
  if len(text.split(' '))>100:
    minutes_text[file_list[i][:8]]='minutes '+text
  else:
    print(i,len(text.split(' ')),text)
# Out:
# 8 10 Monetary policy summary and minutes Monetary Policy Committee voting history
# 12 1
# 50 1
# 55 21 The Governor invited the Committee to vote on the propositions that: The Committee voted unanimously in favour of all four propositions.

# %%
raw_data_speech=pd.DataFrame({'date':speech_text.keys(),'text':speech_text.values()})
raw_data_speech.sort_values(by='date',inplace=True)
raw_data_speech
# Out:
#          date                                               text
# 181  19970225  speech Speech by the Governor at the Queen Eli...
# 157  19970612  speech Lord Mayors Banquet    Speech given by...
# 371  19970624  speech The Sixteenth Mais Lecture    Speech gi...
# 990  19971029  speech The Inflation Target five years on    L...
# 128  19971118  speech Developments in UK financial markets   ...
# ..        ...                                                ...
# 396  20220223  speech The economy and policy trade-offs    Sp...
# 572  20220301  speech The effectiveness of vaccination  again...
# 26   20220330  speech Bank of England      Page 1    Technica...
# 573  20220331  speech Page 1 The road to enhanced payments - ...
# 205  20220404  speech Bank of England      Page 1    Monetary...
#
# [1055 rows x 2 columns]

# %%
raw_data_speech=raw_data_speech.iloc[650:800]

# %%
# !pip install gensim
import gensim
from gensim.summarization import summarize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (6.0.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.6)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 19.8 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 43.6 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.2

# %%
from tqdm import tqdm,trange

# %%
import numpy as np
raw_data_speech['Textrank']=np.nan
for i in trange(len(raw_data_speech)):
  print(i,(int(i)))
  try:
    short_summary = summarize(raw_data_speech.iloc[i,1],word_count=512)
    short_summary=short_summary.replace('\n',' ').replace('\\','')
    raw_data_speech.iloc[i,-1]=short_summary
  except:
    continue
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   0%|          | 0/150 [00:00<?, ?it/s]
# 0 0
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   1%|          | 1/150 [00:00<02:04,  1.19it/s]
# 1 1
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   1%|▏         | 2/150 [00:01<01:17,  1.92it/s]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   2%|▏         | 3/150 [00:01<00:50,  2.94it/s]
# 2 2
# 3 3
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   3%|▎         | 4/150 [00:01<00:36,  4.05it/s]
# 4 4
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   3%|▎         | 5/150 [00:01<00:50,  2.86it/s]
# 5 5
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   4%|▍         | 6/150 [00:02<00:55,  2.60it/s]
# 6 6
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   5%|▍         | 7/150 [00:02<00:48,  2.94it/s]
# 7 7
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   5%|▌         | 8/150 [00:03<00:52,  2.72it/s]
# 8 8
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   6%|▌         | 9/150 [00:05<02:46,  1.18s/it]
# 9 9
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   7%|▋         | 10/150 [00:06<02:18,  1.01it/s]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   7%|▋         | 11/150 [00:06<01:43,  1.34it/s]
# 10 10
# 11 11
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   8%|▊         | 12/150 [00:07<01:37,  1.42it/s]
# 12 12
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   9%|▊         | 13/150 [00:07<01:27,  1.56it/s]
# 13 13
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   9%|▉         | 14/150 [00:09<01:58,  1.15it/s]
# 14 14
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  10%|█         | 15/150 [00:09<01:35,  1.41it/s]
# 15 15
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  11%|█         | 16/150 [00:10<01:39,  1.35it/s]
# 16 16
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  11%|█▏        | 17/150 [00:11<01:33,  1.43it/s]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  12%|█▏        | 18/150 [00:11<01:10,  1.87it/s]
# 17 17
# 18 18
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  13%|█▎        | 19/150 [00:14<02:58,  1.36s/it]
# 19 19
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  13%|█▎        | 20/150 [00:24<08:51,  4.09s/it]
# 20 20
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  14%|█▍        | 21/150 [00:26<07:01,  3.26s/it]
# 21 21
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  15%|█▍        | 22/150 [00:28<06:11,  2.91s/it]
# 22 22
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  15%|█▌        | 23/150 [00:28<04:39,  2.20s/it]
# 23 23
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  16%|█▌        | 24/150 [00:29<03:29,  1.66s/it]
# 24 24
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  17%|█▋        | 25/150 [00:29<02:48,  1.35s/it]
# 25 25
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  17%|█▋        | 26/150 [00:30<02:07,  1.03s/it]
# 26 26
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  18%|█▊        | 27/150 [00:30<01:41,  1.21it/s]
# 27 27
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  19%|█▊        | 28/150 [00:31<01:38,  1.24it/s]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  19%|█▉        | 29/150 [00:31<01:15,  1.59it/s]
# 28 28
# 29 29
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  20%|██        | 30/150 [00:31<01:02,  1.92it/s]
# 30 30
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  21%|██        | 31/150 [00:32<01:03,  1.86it/s]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  21%|██▏       | 32/150 [00:32<00:49,  2.39it/s]
# 31 31
# 32 32
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  22%|██▏       | 33/150 [00:32<00:42,  2.75it/s]
# 33 33
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  23%|██▎       | 34/150 [00:34<01:22,  1.40it/s]
# 34 34
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  23%|██▎       | 35/150 [00:34<01:19,  1.44it/s]
# 35 35
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  24%|██▍       | 36/150 [00:35<01:04,  1.77it/s]
# 36 36
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  25%|██▍       | 37/150 [00:36<01:14,  1.52it/s]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  25%|██▌       | 38/150 [00:36<00:55,  2.00it/s]
# 37 37
# 38 38
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  26%|██▌       | 39/150 [00:36<00:47,  2.35it/s]
# 39 39
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  27%|██▋       | 40/150 [00:36<00:42,  2.57it/s]
# 40 40
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  27%|██▋       | 41/150 [00:41<03:02,  1.68s/it]
# 41 41
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  28%|██▊       | 42/150 [00:45<04:30,  2.51s/it]
# 42 42
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  29%|██▊       | 43/150 [00:46<03:20,  1.87s/it]
# 43 43
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  29%|██▉       | 44/150 [00:46<02:37,  1.48s/it]
# 44 44
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  30%|███       | 45/150 [00:47<02:19,  1.33s/it]
# 45 45
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  31%|███       | 46/150 [00:48<02:04,  1.20s/it]
# 46 46
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  31%|███▏      | 47/150 [00:50<02:28,  1.44s/it]/usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  32%|███▏      | 48/150 [00:50<01:47,  1.06s/it]
# 47 47
# 48 48
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  33%|███▎      | 49/150 [00:51<01:26,  1.17it/s]
# 49 49
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  33%|███▎      | 50/150 [00:53<02:12,  1.33s/it]
# 50 50
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  34%|███▍      | 51/150 [00:53<01:39,  1.01s/it]
# 51 51
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  35%|███▍      | 52/150 [00:54<01:39,  1.01s/it]
# 52 52
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  35%|███▌      | 53/150 [00:55<01:31,  1.06it/s]
# 53 53
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  36%|███▌      | 54/150 [00:56<01:11,  1.33it/s]
# 54 54
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  37%|███▋      | 55/150 [00:56<01:03,  1.49it/s]
# 55 55
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 100%|██████████| 150/150 [01:42<00:00,  1.46it/s]

# %%
from transformers import pipeline
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Downloading:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]

# %%
raw_data_speech
# Out:
#           date                                               text  \
# 336   20141210  speech Monetary policy in an uncertain economy...
# 1016  20150120  speech Financial stability, the Single Market ...
# 514   20150122  speech Regulation and the future of the insura...
# 394   20150123  speech Cyber resilience: a financial stability...
# 101   20150126  speech Risks around the forecast    Speech giv...
# ...        ...                                                ...
# 399   20170303  speech Harrowing the ploughed field  Refini...
# 603   20170307  speech Watching the watchers:  forward-looking...
# 739   20170320  speech Productivity puzzles    Speech given by...
# 525   20170321  speech Remarks at the Banking Standards Board ...
# 344   20170323  speech Brexit and the pound    Speech given by...
#
#                                                Textrank
# 336   I will set out my judgment of the  balance of ...
# 1016  speech Financial stability, the Single Market ...
# 514   speech Regulation and the future of the insura...
# 394   Detecting threats,  being ready to respond to ...
# 101   (It is worth noting  that this forecast was do...
# ...                                                 ...
# 399   speech Harrowing the ploughed field  Refini...
# 603   All of that has changed in recent years as cen...
# 739   It certainly seems likely that official statis...
# 525   Law, ethics and culture in banking      Mark ...
# 344   1    All speeches are available online at www....
#
# [150 rows x 3 columns]

# %%
for i in trange(len(raw_data_speech)):
  if (int(i)%20==0):
    print('save ',i)
    raw_data_speech.to_csv('/content/gdrive/MyDrive/JPM_NLP/Code/raw_uk_speech2_2.csv')
  text=raw_data_speech.iloc[i,1]
  new_text=""
  start=0
  try:
    while start<len(text.split( )):
      summarized = summarizer(' '.join(text.split(' ')[start:start+700]), min_length=50, max_length=80)
      new_text+=" "+summarized[0]['summary_text']
      start+=700
    print(len(new_text.split(' ')))
    raw_data_speech.iloc[i,-1]=new_text
  except:
    continue
raw_data_speech.to_csv('/content/gdrive/MyDrive/JPM_NLP/Code/raw_uk_speech2_2.csv')
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# save  0
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#   1%|          | 1/150 [02:25<6:01:59, 145.77s/it]
# 518
#   1%|▏         | 2/150 [03:57<4:41:22, 114.07s/it]
# 367
#   2%|▏         | 3/150 [04:46<3:26:15, 84.19s/it]
# 172
#   3%|▎         | 4/150 [05:31<2:47:33, 68.86s/it]
# 166
#   3%|▎         | 5/150 [08:01<3:57:05, 98.10s/it]
# 557
#   4%|▍         | 6/150 [10:00<4:12:19, 105.14s/it]
# 440
#   5%|▍         | 7/150 [11:37<4:04:16, 102.49s/it]
# 382
#   5%|▌         | 8/150 [12:50<3:40:24, 93.13s/it]
# 284
# Token indices sequence length is longer than the specified maximum sequence length for this model (1503 > 1024). Running this sequence through the model will result in indexing errors
#   7%|▋         | 10/150 [18:18<4:52:34, 125.39s/it]
# 401
#   7%|▋         | 11/150 [19:04<3:53:48, 100.92s/it]
# 171
#   8%|▊         | 12/150 [20:50<3:55:29, 102.39s/it]
# 380
#   9%|▊         | 13/150 [22:05<3:35:10, 94.24s/it]
# 263
#   9%|▉         | 14/150 [24:45<4:18:53, 114.22s/it]
# 619
#  10%|█         | 15/150 [25:29<3:29:03, 92.92s/it]
# 164
#  11%|█         | 16/150 [27:22<3:41:13, 99.06s/it]
# 454
#  11%|█▏        | 17/150 [28:35<3:22:05, 91.17s/it]
# 273
#  12%|█▏        | 18/150 [29:03<2:38:45, 72.16s/it]
# 85
#  13%|█▎        | 20/150 [35:49<5:13:15, 144.58s/it]
# save  20
#  14%|█▍        | 21/150 [37:58<5:00:49, 139.92s/it]
# 484
#  15%|█▍        | 22/150 [41:01<5:25:48, 152.72s/it]
# 730
#  15%|█▌        | 23/150 [42:57<5:00:27, 141.95s/it]
# 450
#  16%|█▌        | 24/150 [44:15<4:17:34, 122.65s/it]
# 305
#  17%|█▋        | 25/150 [46:03<4:06:31, 118.33s/it]
# 375
#  17%|█▋        | 26/150 [47:45<3:54:28, 113.46s/it]
# 412
#  18%|█▊        | 27/150 [49:03<3:30:49, 102.84s/it]
# 304
#  19%|█▊        | 28/150 [50:51<3:32:00, 104.26s/it]
# 450
#  19%|█▉        | 29/150 [51:24<2:47:20, 82.98s/it]
# 125
#  20%|██        | 30/150 [52:52<2:48:56, 84.47s/it]
# 328
#  21%|██        | 31/150 [54:53<3:09:22, 95.48s/it]
# 495
#  21%|██▏       | 32/150 [55:53<2:46:23, 84.61s/it]
# 200
#  22%|██▏       | 33/150 [56:38<2:22:01, 72.84s/it]
# 175
#  23%|██▎       | 35/150 [1:02:09<3:48:28, 119.21s/it]
# 577
#  24%|██▍       | 36/150 [1:03:11<3:13:58, 102.09s/it]
# 246
#  25%|██▍       | 37/150 [1:05:24<3:29:20, 111.15s/it]
# 528
#  25%|██▌       | 38/150 [1:06:10<2:50:53, 91.55s/it]
# 175
#  26%|██▌       | 39/150 [1:07:58<2:58:58, 96.74s/it]
# 428
#  27%|██▋       | 40/150 [1:09:14<2:45:46, 90.42s/it]
# 295
# save  40
#  27%|██▋       | 41/150 [1:13:01<3:58:42, 131.40s/it]
# 888
#  29%|██▊       | 43/150 [1:17:13<3:41:55, 124.44s/it]
# 295
#  29%|██▉       | 44/150 [1:18:59<3:30:09, 118.96s/it]
# 408
#  30%|███       | 45/150 [1:21:21<3:40:26, 125.97s/it]
# 544
#  31%|███       | 46/150 [1:23:29<3:39:23, 126.57s/it]
# 453
#  31%|███▏      | 47/150 [1:26:24<4:02:21, 141.18s/it]
# 652
#  32%|███▏      | 48/150 [1:27:12<3:12:08, 113.03s/it]
# 208
#  33%|███▎      | 49/150 [1:28:31<2:53:11, 102.89s/it]
# 284
#  33%|███▎      | 50/150 [1:31:48<3:38:19, 130.99s/it]
# 775
#  34%|███▍      | 51/150 [1:32:30<2:52:27, 104.52s/it]
# 164
#  35%|███▌      | 53/150 [1:36:16<2:56:22, 109.10s/it]
# 443
#  36%|███▌      | 54/150 [1:37:46<2:45:13, 103.27s/it]
# 357
#  37%|███▋      | 55/150 [1:39:39<2:48:13, 106.24s/it]
# 414
#  37%|███▋      | 56/150 [1:41:11<2:39:43, 101.95s/it]
# 381
#  38%|███▊      | 57/150 [1:42:43<2:33:27, 99.00s/it]
# 354
#  39%|███▊      | 58/150 [1:43:27<2:06:26, 82.46s/it]
# 168
#  39%|███▉      | 59/150 [1:43:55<1:40:23, 66.20s/it]
# 104
#  40%|████      | 60/150 [1:45:44<1:58:32, 79.03s/it]
# 426
# save  60
#  41%|████      | 61/150 [1:46:39<1:46:44, 71.96s/it]
# 234
#  42%|████▏     | 63/150 [1:52:13<2:47:06, 115.25s/it]
# 407
#  43%|████▎     | 64/150 [1:53:12<2:20:55, 98.32s/it]
# 201
#  43%|████▎     | 65/150 [1:53:58<1:57:08, 82.69s/it]
# 176
#  44%|████▍     | 66/150 [1:55:45<2:06:07, 90.09s/it]
# 462
#  45%|████▍     | 67/150 [1:57:07<2:01:18, 87.70s/it]
# 326
#  47%|████▋     | 70/150 [2:05:28<3:04:00, 138.00s/it]
# 581
#  48%|████▊     | 72/150 [2:10:41<2:59:59, 138.46s/it]
# 206
#  49%|████▊     | 73/150 [2:11:57<2:33:19, 119.47s/it]
# 319
#  49%|████▉     | 74/150 [2:13:56<2:31:16, 119.43s/it]
# 475
#  51%|█████     | 76/150 [2:15:47<1:51:54, 90.74s/it]
# 366
#  51%|█████▏    | 77/150 [2:17:30<1:54:39, 94.25s/it]
# 364
#  52%|█████▏    | 78/150 [2:19:16<1:57:13, 97.69s/it]
# 408
#  53%|█████▎    | 79/150 [2:21:05<1:59:54, 101.32s/it]
# 413
#  53%|█████▎    | 80/150 [2:23:33<2:14:16, 115.10s/it]
# 554
# save  80
#  54%|█████▍    | 81/150 [2:25:18<2:08:51, 112.06s/it]
# 425
#  55%|█████▌    | 83/150 [2:29:36<2:08:02, 114.66s/it]
# 264
#  57%|█████▋    | 85/150 [2:32:10<1:40:07, 92.42s/it]
# 163
#  57%|█████▋    | 86/150 [2:33:53<1:42:05, 95.71s/it]
# 427
#  58%|█████▊    | 87/150 [2:34:39<1:24:46, 80.73s/it]
# 188
#  59%|█████▊    | 88/150 [2:35:52<1:21:08, 78.53s/it]
# 262
#  59%|█████▉    | 89/150 [2:37:42<1:29:24, 87.93s/it]
# 452
#  60%|██████    | 90/150 [2:38:49<1:21:33, 81.56s/it]
# 233
#  61%|██████    | 91/150 [2:40:53<1:32:45, 94.33s/it]
# 449
#  61%|██████▏   | 92/150 [2:42:58<1:40:00, 103.46s/it]
# 485
#  62%|██████▏   | 93/150 [2:44:11<1:29:48, 94.53s/it]
# 266
#  63%|██████▎   | 94/150 [2:44:57<1:14:39, 79.99s/it]
# 175
#  63%|██████▎   | 95/150 [2:45:40<1:02:54, 68.63s/it]
# 179
#  64%|██████▍   | 96/150 [2:46:42<1:00:09, 66.85s/it]
# 181
#  65%|██████▌   | 98/150 [2:53:55<2:07:18, 146.89s/it]
# 921
#  67%|██████▋   | 100/150 [2:58:55<2:00:31, 144.63s/it]
# 394
# save  100
#  67%|██████▋   | 101/150 [3:00:43<1:49:07, 133.62s/it]
# 383
#  68%|██████▊   | 102/150 [3:02:33<1:41:16, 126.59s/it]
# 404
#  69%|██████▊   | 103/150 [3:04:40<1:39:16, 126.74s/it]
# 486
#  70%|███████   | 105/150 [3:11:38<2:06:01, 168.02s/it]
# 787
#  71%|███████   | 106/150 [3:12:50<1:42:03, 139.18s/it]
# 257
#  71%|███████▏  | 107/150 [3:13:40<1:20:33, 112.40s/it]
# 161
#  72%|███████▏  | 108/150 [3:15:27<1:17:32, 110.77s/it]
# 352
#  73%|███████▎  | 109/150 [3:16:28<1:05:28, 95.82s/it]
# 213
#  73%|███████▎  | 110/150 [3:18:46<1:12:17, 108.43s/it]
# 483
#  74%|███████▍  | 111/150 [3:19:49<1:01:40, 94.89s/it]
# 214
#  75%|███████▍  | 112/150 [3:21:00<55:30, 87.65s/it]
# 246
#  75%|███████▌  | 113/150 [3:22:20<52:39, 85.39s/it]
# 304
#  76%|███████▌  | 114/150 [3:25:12<1:06:44, 111.23s/it]
# 594
#  77%|███████▋  | 115/150 [3:27:29<1:09:28, 119.09s/it]
# 462
#  78%|███████▊  | 117/150 [3:28:41<44:20, 80.63s/it]
# 222
#  79%|███████▉  | 119/150 [3:31:46<44:56, 86.99s/it]
# 384
#  80%|████████  | 120/150 [3:33:37<46:44, 93.48s/it]
# 429
# save  120
#  81%|████████  | 121/150 [3:34:25<39:03, 80.81s/it]
# 181
#  81%|████████▏ | 122/150 [3:40:14<1:13:24, 157.29s/it]
# 1181
#  82%|████████▏ | 123/150 [3:42:05<1:04:48, 144.02s/it]
# 433
#  83%|████████▎ | 124/150 [3:42:51<49:54, 115.17s/it]
# 162
#  83%|████████▎ | 125/150 [3:45:53<56:10, 134.81s/it]
# 692
#  84%|████████▍ | 126/150 [3:48:08<53:58, 134.93s/it]
# 449
#  85%|████████▌ | 128/150 [3:51:27<41:46, 113.91s/it]
# 216
#  86%|████████▌ | 129/150 [3:54:37<47:44, 136.39s/it]
# 657
#  87%|████████▋ | 130/150 [3:57:51<51:14, 153.72s/it]
# 705
#  88%|████████▊ | 132/150 [4:01:28<37:12, 124.05s/it]
# 117
#  89%|████████▊ | 133/150 [4:02:13<28:27, 100.44s/it]
# 159
#  89%|████████▉ | 134/150 [4:03:04<22:51, 85.73s/it]
# 179
#  90%|█████████ | 135/150 [4:05:15<24:47, 99.18s/it]
# 477
#  93%|█████████▎| 139/150 [4:12:00<18:29, 100.90s/it]
# 354
#  93%|█████████▎| 140/150 [4:13:59<17:41, 106.14s/it]
# 382
# save  140
#  94%|█████████▍| 141/150 [4:16:50<18:50, 125.62s/it]
# 625
#  95%|█████████▍| 142/150 [4:19:14<17:28, 131.10s/it]
# 535
#  96%|█████████▌| 144/150 [4:21:58<10:28, 104.74s/it]
# 229
#  97%|█████████▋| 145/150 [4:24:31<09:55, 119.20s/it]
# 524
#  97%|█████████▋| 146/150 [4:25:39<06:55, 103.89s/it]
# 252
#  99%|█████████▊| 148/150 [4:31:38<05:08, 154.25s/it]
# 1052
#  99%|█████████▉| 149/150 [4:32:46<02:08, 128.39s/it]
# 234
# 100%|██████████| 150/150 [4:34:58<00:00, 109.99s/it]
# 470
